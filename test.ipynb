# %%
from openai import OpenAI
Client = OpenAI(api_key="0",base_url = "http://0.0.0.0:8080/v1")
messages = [{"role":"user","content":"Who are you?"}]
result = Client.chat.completions.create(messages=messages,model="LLM-Research/Meta-Llama-3-8B-Instruct")
print(result.choices[0].message)

messages = [{"role":"user","content":"你是来自哪家公司的聊天机器人"}]
result = Client.chat.completions.create(messages=messages,model="LLM-Research/Meta-Llama-3-8B-Instruct")
print(result.choices[0].message)

messages = [{"role":"user","content":"请自我介绍一下"}]
result = Client.chat.completions.create(messages=messages,model="LLM-Research/Meta-Llama-3-8B-Instruct")
print(result.choices[0].message)

messages = [{"role":"user","content":"请生成金融领域的一些相关术语"}]
result = Client.chat.completions.create(messages=messages,model="LLM-Research/Meta-Llama-3-8B-Instruct")
print(result.choices[0].message)
# Out:
# ChatCompletionMessage(content="I am LLaMA, an AI assistant developed by Meta AI that can understand and respond to human input in a conversational manner. I'm not a human, but a computer program designed to simulate conversation, answer questions, and even generate text based on the input I receive. I can be trained on a wide range of topics and can adapt to different contexts and styles of communication. I'm here to help answer your questions, provide information, and even engage in fun conversations!", refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None)
# ChatCompletionMessage(content='我是人工智能语言科技有限公司的聊天机器人。该公司专注于自然语言处理技术的研究与开发，致力于构建智能交互平台，并应用于多个场景包括客户服务、信息推送以及智能助手等领域。我当前的功能主要体现在文本对话能力上，能够理解用户输入的自由式短文本，基于训练数据进行-contextual-响应生成，支持开关机、时间、日期、weather、定位等基本交互，具备一定的共感能力和流畅性。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None)
# ...
